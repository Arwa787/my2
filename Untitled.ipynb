# %%
pip install pandas
# Out:
# ...
# Note: you may need to restart the kernel to use updated packages.

# %%
import pandas as pd 
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
listing=pd.read_csv('listings.csv')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 404 entries, 0 to 403
# Data columns (total 75 columns):
#  #   Column                                        Non-Null Count  Dtype
# ---  ------                                        --------------  -----
#  0   id                                            404 non-null    int64
#  1   listing_url                                   404 non-null    object
#  2   scrape_id                                     404 non-null    int64
#  3   last_scraped                                  404 non-null    object
#  4   source                                        404 non-null    object
#  5   name                                          404 non-null    object
#  6   description                                   392 non-null    object
#  7   neighborhood_overview                         245 non-null    object
#  8   picture_url                                   404 non-null    object
# ...

# %%
listing.describe()
# Out:
#         id  scrape_id  host_id  host_listings_count  \
# count  0.0        0.0      0.0                  0.0
# mean   NaN        NaN      NaN                  NaN
# std    NaN        NaN      NaN                  NaN
# min    NaN        NaN      NaN                  NaN
# 25%    NaN        NaN      NaN                  NaN
# 50%    NaN        NaN      NaN                  NaN
# 75%    NaN        NaN      NaN                  NaN
# max    NaN        NaN      NaN                  NaN
#
#        host_total_listings_count  neighbourhood_group_cleansed  latitude  \
# count                        0.0                           0.0       0.0
# mean                         NaN                           NaN       NaN
# std                          NaN                           NaN       NaN
# min                          NaN                           NaN       NaN
# 25%                          NaN                           NaN       NaN
# ...

# %%
listing.drop_duplicates(inplace=True)

# %%
listing.dropna(inplace=True)

# %%
from scipy import stats
z_scores = np.abs(stats.zscore(listing['price']))
listing = listing[(z_scores < 3)]

# %%
sns.pairplot(listing[['price', 'bedrooms', 'host_location', 'host_id']])
plt.title('Pairplot of Price, Availability, Minimum Nights, and Number of Reviews')
plt.show()

# %%
correlation_matrix = listing.corr()
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()
# Out:
# C:\Users\Arwa7\Downloads\anacc\Lib\site-packages\seaborn\matrix.py:202: RuntimeWarning: All-NaN slice encountered
#   vmin = np.nanmin(calc_data)
# C:\Users\Arwa7\Downloads\anacc\Lib\site-packages\seaborn\matrix.py:207: RuntimeWarning: All-NaN slice encountered
#   vmax = np.nanmax(calc_data)
# C:\Users\Arwa7\Downloads\anacc\Lib\site-packages\seaborn\matrix.py:260: FutureWarning: Format strings passed to MaskedConstant are ignored, but in future may error or produce different behavior
#   annotation = ("{:" + self.fmt + "}").format(val)
